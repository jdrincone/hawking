# %%
import sys
import os
import numpy as np
import pandas as pd
from typing import  Optional, Callable, Dict
from collections.abc import Mapping
import re, unicodedata


sys.path.append(os.path.abspath('..'))
from core.s3 import S3AssetManager

from core.viz import (
        plot_gauge_grid,
        plot_bar,
        plot_heatmap,
        plot_pie,
        plot_time_heatmap
)

# %%
notebook_name = "exp_aliforte_prod_reprocesos"
s3 = S3AssetManager(notebook_name=notebook_name)

# %%
df_prod = s3.read_csv(f"s3://{s3.bucket_name}/data/aliforte_production/ops_pel.csv")
df_prod.head()
# Out:
#          date start_time  end_time accumulated_time  downtime feed_type  \
# 0  2025-04-08   12:20:00  15:00:00         03:45:00  00:00:00      HY-8
# 1  2025-04-08   15:00:00  16:05:00              NaN  00:00:00      HY-8
# 2  2025-04-08   16:05:00  17:12:00         01:07:00  00:00:00      HY-1
# 3  2025-04-08   17:12:00  18:55:00         01:43:00  00:00:00       E-1
# 4  2025-05-08   10:00:00  15:00:00         11:00:00  00:00:00       E-1
#
#        lot  quantity_tm  temperature_c         operator  ...   accumulated_td  \
# 0  31067.0          NaN           80.2  Jose Benalcazar  ...  0 days 03:45:00
# 1  31067.0         10.0           80.3    Johnny Tirira  ...              NaN
# 2  31065.0          2.0           76.2    Johnny Tirira  ...  0 days 01:07:00
# 3  31073.0          3.0           73.2    Johnny Tirira  ...  0 days 01:43:00
# 4  31076.0          NaN           82.1  Jose Benalcazar  ...  0 days 11:00:00
#
#         hour  downtime_str      downtime_td  downtime_hour  \
# 0   3.750000      00:00:00  0 days 00:00:00            0.0
# 1        NaN      00:00:00  0 days 00:00:00            0.0
# 2   1.116667      00:00:00  0 days 00:00:00            0.0
# 3   1.716667      00:00:00  0 days 00:00:00            0.0
# 4  11.000000      00:00:00  0 days 00:00:00            0.0
#
#             start_hour             ts_round  normalize_notes details_notes  \
# 0  2025-04-08 12:20:00  2025-04-08 12:00:00              NaN    Productivo
# 1  2025-04-08 15:00:00  2025-04-08 15:00:00              NaN    Productivo
# 2  2025-04-08 16:05:00  2025-04-08 16:00:00              NaN    Productivo
# 3  2025-04-08 17:12:00  2025-04-08 17:00:00              NaN    Productivo
# 4  2025-05-08 10:00:00  2025-05-08 10:00:00              NaN    Productivo
#
#           specie
# 0  reproductoras
# 1  reproductoras
# 2  reproductoras
# 3        broiler
# 4        broiler
#
# [5 rows x 23 columns]

# %%
reprocess = pd.read_excel("../raw/Consolidado reprocesos.xlsx", sheet_name="Consolidado")
reprocess.columns = reprocess.columns.str.strip().str.lower()
reprocess.rename(columns={"lote": "lot", "cantidad kilos": "repro_kg", "causa reproceso": "repro_cause"}, inplace=True)

# %%
reprocess["lot"].duplicated().sum()
# Out:
# 6

# %%
reprocess[reprocess.duplicated(subset=["lot"], keep=False)]
# Out:
#     unnamed: 0      mes                          código    lot  repro_kg  \
# 15         NaN    MARZO                              C1  30055      4920
# 16         NaN    MARZO                              C1  30055      5000
# 23         NaN    MARZO                            APE2  30166      3560
# 24         NaN    MARZO                            APE2  30166       780
# 49         NaN    JUNIO                             BAF  30448       160
# 50         NaN    JUNIO                             BAF  30448       840
# 59         NaN    JUNIO                    Mezcla de PT    NaN      3080
# 60         NaN    JUNIO                    Mezcla de MP    NaN      2640
# 70         NaN   AGOSTO                            PF01  31118       695
# 73         NaN   AGOSTO                            PF01  31118      1875
# 77         NaN  OCTUBRE  Mezcla MP (maíz, trigo y soya)    NaN      1840
#
#         repro_cause     responsable
# 15  DIFERENTE COLOR       Nutrición
# 16  DIFERENTE COLOR       Nutrición
# 23           MOJADO      Producción
# 24           MOJADO      Producción
# 49           MOJADO          Ventas
# 50           MOJADO          Ventas
# 59          RESIDUO      Producción
# 60          RESIDUO      Producción
# 70           GRUMOS      Producción
# 73     DOSIFICACION  Jonathan Gomez
# 77         MEZCLADO      Producción

# %%
reprocess = reprocess.drop_duplicates(subset=["lot"], keep="last")

# %%
rev = pd.merge(
    df_prod, 
    reprocess,
    on="lot",
    how="left"
)

rev["repross"] = np.where(rev["repro_kg"]>0, "S", "N")

# %%
rev["repross"].value_counts(dropna=False)
# Out:
# N    947
# S     21
# Name: repross, dtype: int64

# %%
# 1. Usamos to_datetime con errors='coerce'
# 'coerce' es clave: si hay una celda con basura, la convierte en NaT (nulo) en vez de romper el código
rev['start_dt'] = pd.to_datetime(rev['start_time'].astype(str), errors='coerce')
rev['end_dt'] = pd.to_datetime(rev['end_time'].astype(str), errors='coerce')

# 2. Calculamos la diferencia
rev['diff'] = rev['end_dt'] - rev['start_dt']

# 3. Convertimos a horas
rev['horas_diferencia'] = rev['diff'].dt.total_seconds() / 3600

# 4. Corrección para turnos nocturnos (ej: empieza 23:00, termina 02:00)
# Si la diferencia es negativa, significa que cruzó la medianoche, sumamos 24h
rev.loc[rev['horas_diferencia'] < 0, 'horas_diferencia'] += 24
rev["performance"] = rev["quantity_tm"] / rev["horas_diferencia"]

# %%
rev.columns
# Out:
# Index(['date', 'start_time', 'end_time', 'accumulated_time', 'downtime',
#        'feed_type', 'lot', 'quantity_tm', 'temperature_c', 'operator', 'notes',
#        'pellet', 'month', 'accumulated_td', 'hour', 'downtime_str',
#        'downtime_td', 'downtime_hour', 'start_hour', 'ts_round',
#        'normalize_notes', 'details_notes', 'specie', 'unnamed: 0', 'mes',
#        'código', 'repro_kg', 'repro_cause', 'responsable', 'repross',
#        'start_dt', 'end_dt', 'start_delta', 'diff', 'horas_diferencia',
#        'performance'],
#       dtype='object')

# %%
rev[rev['repross']=='S'][['lot', 'pellet', 'date', 'feed_type', 'specie', "performance",
 'start_time', 'end_time', 'hour', 'horas_diferencia', 'normalize_notes', 'repro_kg', 'quantity_tm',  'repro_cause']]
# Out:
#          lot    pellet        date  feed_type         specie  performance  \
# 12   31129.0  pellet 1  2025-12-08       HY-7  reproductoras     4.000000
# 98   31422.0  pellet 1  2025-09-20        APP       ponedora          NaN
# 99   31422.0  pellet 1  2025-09-22        APP       ponedora          NaN
# 107  31422.0  pellet 1  2025-09-25        APP       ponedora          NaN
# 254  31131.0  pellet 2  2025-08-08       PF02         cerdos     1.793103
# 255  31118.0  pellet 2  2025-08-08       PF01         cerdos     0.923077
# 276  31178.0  pellet 2  2025-08-16        BAI       ponedora          NaN
# 277  31178.0  pellet 2  2025-08-16        BAI       ponedora          NaN
# 278  31178.0  pellet 2  2025-08-18        BAI       ponedora     6.153846
# 371  31387.0  pellet 2  2025-09-15         CF         cerdos          NaN
# 372  31387.0  pellet 2  2025-09-16         CF         cerdos    72.000000
# 558  31726.0  pellet 2  2025-11-10         C1          cuyes     2.500000
# 763  31387.0  pellet 3  2025-09-15         CF         cerdos     4.941176
# 778  31427.0  pellet 3  2025-09-22        E-1        broiler          NaN
# 779  31427.0  pellet 3  2025-09-23        E-1        broiler     1.833333
# 798  31484.0  pellet 3  2025-09-30         G3      ganaderia     5.625000
# 866  31642.0  pellet 3  2025-10-27        BCC         cerdos          NaN
# 867  31642.0  pellet 3  2025-10-28        BCC         cerdos    10.702703
# 893  31683.0  pellet 3  2025-11-01  F2 PREMEX         cerdos     8.250000
# 935  31781.0  pellet 3  2025-11-18        BCG         cerdos     3.191489
# 964  31833.0  pellet 3  2025-11-27         P3         cerdos     5.000000
#
#     start_time  end_time       hour  horas_diferencia normalize_notes  \
# 12    13:00:00  14:00:00   1.000000          1.000000             NaN
# 98    07:40:00  13:00:00   5.333333          5.333333             NaN
# 99    08:30:00  14:30:00   6.000000          6.000000         Atasque
# 107   08:10:00  11:25:00   3.250000          3.250000             NaN
# 254   10:10:00  17:25:00   7.250000          7.250000             NaN
# 255   18:10:00  21:25:00   3.250000          3.250000             NaN
# 276   09:35:00  12:00:00  10.750000          2.416667             NaN
# 277   12:00:00  18:00:00        NaN          6.000000             NaN
# 278   06:00:00  09:15:00        NaN          3.250000   Falla Caldero
# 371   13:50:00  16:30:00   2.666667          2.666667             NaN
# 372   07:00:00  07:25:00   0.416667          0.416667             NaN
# 558   17:50:00  21:50:00        NaN          4.000000             NaN
# 763   14:20:00  15:45:00   1.416667          1.416667             NaN
# 778   14:00:00  16:00:00   2.000000          2.000000             NaN
# 779   07:00:00  13:00:00   6.000000          6.000000             NaN
# 798   19:20:00  22:00:00   2.666667          2.666667             NaN
# 866   19:00:00  22:00:00   3.000000          3.000000             NaN
# 867   08:30:00  11:35:00   3.083333          3.083333             NaN
# 893   08:00:00  09:20:00        NaN          1.333333             NaN
# 935   14:50:00  16:24:00        NaN          1.566667             NaN
# 964   17:40:00  19:40:00        NaN          2.000000             NaN
#
#      repro_kg  quantity_tm      repro_cause
# 12     4040.0          4.0     PROGRAMACIÓN
# 98     3600.0          NaN          QUEMADO
# 99     3600.0          NaN          QUEMADO
# 107    3600.0          NaN          QUEMADO
# 254   12575.0         13.0     DOSIFICACION
# 255    1875.0          3.0     DOSIFICACION
# 276    2400.0          NaN           GRUMOS
# 277    2400.0          NaN           GRUMOS
# 278    2400.0         20.0           GRUMOS
# 371   14360.0          NaN         CADUCADO
# 372   14360.0         30.0         CADUCADO
# 558   10280.0         10.0  DIFERENTE COLOR
# 763   14360.0          7.0         CADUCADO
# 778     600.0          NaN          QUEMADO
# 779     600.0         11.0          QUEMADO
# 798      40.0         15.0           MOJADO
# 866    8660.0          NaN     DOSIFICACION
# 867    8660.0         33.0     DOSIFICACION
# 893    2000.0         11.0     PROGRAMACIÓN
# 935     620.0          5.0         MEZCLADO
# 964    1160.0         10.0     DOSIFICACION

# %%
notes_join = lambda s: ", ".join(
    s.dropna()
     .astype(str)
     .str.strip()
     .loc[lambda x: x.ne("")]
     .unique()
)

# %%
qa_proccess =rev[rev['repross'] == 'S'].groupby(["pellet", "responsable", "operator"], dropna=False).agg(
    repro_kg=("repro_kg", "sum"),
    count=("lot", "count"),
    quantity_tm=("quantity_tm", "sum"),
    causa=('repro_cause', notes_join),
).reset_index()
qa_proccess["repro_tm"] = qa_proccess["repro_kg"] / 1_000
qa_proccess["razon_qa"] = qa_proccess["repro_tm"] / qa_proccess["quantity_tm"]*100
qa_proccess
# Out:
#       pellet                 responsable         operator  repro_kg  count  \
# 0   pellet 1             Jose Benalcazar  Jose Benalcazar   10800.0      3
# 1   pellet 1                      Ventas    Johnny Tirira    4040.0      1
# 2   pellet 2              Jonathan Gomez     Brayan Erazo   14450.0      2
# 3   pellet 2              Jonathan Gomez    Johnny Tirira   10280.0      1
# 4   pellet 2  José Cabezas y Bryan Erazo     Brayan Erazo    4800.0      2
# 5   pellet 2  José Cabezas y Bryan Erazo     Jose Cabezas    2400.0      1
# 6   pellet 2                      Ventas     Brayan Erazo   28720.0      2
# 7   pellet 3                 Bryan Erazo     Brayan Erazo     620.0      1
# 8   pellet 3             Jordan Gallegos     Brayan Erazo    8660.0      1
# 9   pellet 3             Jordan Gallegos     Jose Cabezas    8660.0      1
# 10  pellet 3  José Cabezas y Bryan Erazo     Jose Cabezas    1200.0      2
# 11  pellet 3                  Producción     Brayan Erazo    2000.0      1
# 12  pellet 3                  Producción     Jose Cabezas    1160.0      1
# 13  pellet 3                      Ventas     Brayan Erazo   14360.0      1
# 14  pellet 3                      Ventas     Jose Cabezas      40.0      1
#
#     quantity_tm            causa  repro_tm    razon_qa
# 0           0.0          QUEMADO     10.80         inf
# 1           4.0     PROGRAMACIÓN      4.04  101.000000
# 2          16.0     DOSIFICACION     14.45   90.312500
# 3          10.0  DIFERENTE COLOR     10.28  102.800000
# 4          20.0           GRUMOS      4.80   24.000000
# 5           0.0           GRUMOS      2.40         inf
# 6          30.0         CADUCADO     28.72   95.733333
# 7           5.0         MEZCLADO      0.62   12.400000
# 8          33.0     DOSIFICACION      8.66   26.242424
# 9           0.0     DOSIFICACION      8.66         inf
# 10         11.0          QUEMADO      1.20   10.909091
# 11         11.0     PROGRAMACIÓN      2.00   18.181818
# 12         10.0     DOSIFICACION      1.16   11.600000
# 13          7.0         CADUCADO     14.36  205.142857
# 14         15.0           MOJADO      0.04    0.266667

# %%
qa_proccess =rev[rev['repross'] == 'S'].groupby(["operator"], dropna=False).agg(
    repro_kg=("repro_kg", "sum"),
    count=("lot", "count"),
    quantity_tm=("quantity_tm", "sum"),
    causa=('repro_cause', notes_join),
).reset_index()
qa_proccess["repro_tm"] = qa_proccess["repro_kg"] / 1_000
qa_proccess["razon_qa"] = qa_proccess["repro_tm"] / qa_proccess["quantity_tm"]*100
qa_proccess
# Out:
#           operator  repro_kg  count  quantity_tm  \
# 0     Brayan Erazo   73610.0     10        122.0
# 1    Johnny Tirira   14320.0      2         14.0
# 2  Jose Benalcazar   10800.0      3          0.0
# 3     Jose Cabezas   13460.0      6         36.0
#
#                                                causa  repro_tm    razon_qa
# 0  DOSIFICACION, GRUMOS, CADUCADO, PROGRAMACIÓN, ...     73.61   60.336066
# 1                      PROGRAMACIÓN, DIFERENTE COLOR     14.32  102.285714
# 2                                            QUEMADO     10.80         inf
# 3              GRUMOS, QUEMADO, MOJADO, DOSIFICACION     13.46   37.388889
